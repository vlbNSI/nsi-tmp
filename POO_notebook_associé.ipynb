# %% [markdown]
# <table>   <tr>
#     <td>Numérique et Sciences Informatiques -  Terminale                                                          </td>
#     <td><img src="images/logo.jpg"      alt="St Joseph-La Salle LORIENT" width="50" height="48"></td>
#     </tr>
# </table>
#
# <b>Structures de données et Langages</b>
#
# # <center> <b>La Programmation Orientée Objet (POO)</b>  </center>
# ### Notebook associé au cours

# %% [markdown]
# # Activité : Creation d'un Humain

# %%
# Exercice 1.1

# %%
# Exercice 1.2

# %%
# Exercice 1.3

# %%
# Exercice 1.4

#Votre code
    
    def deplacement(self):
        self.x+=randint(-1,1)
        self.y+=randint(-1,1)
        if 5<=self.x<9 and 2<self.y<=7:
            self.anniversaire()
            self.affiche_etat()
            
    #Votre code

def marche_aleatoire(nombre_de_mouvements:int):
    #creation des Humains#
    alice=Humain("Alice",17)
    bob=Humain("Bobby",16,1,1)
    
    #Marche aleatoire#
    resultats_distances=[]
    for i in range(nombre_de_mouvements):   
        resultats_distances.append(alice.distance(bob))
        alice.deplacement()
        bob.deplacement()        
    numero_mouvement=[i for i in range(nombre_de_mouvements)]
        
    #Pour le graphique#
    
    #Votre code
        
#Votre code

# %%
# Definition 1.7

class Voiture:
    def __init__(self, couleur):
        self.__couleur = couleur

        
    #Votre code

# %% [markdown]
# # Quelques exercices

# %%
# Exercice 1.5  Lord of the Onion Rings

#Votre code
    

if __name__ == "__main__":
    
    #Votre code

# %%
# Exercice 1.6 : Une fraction 

#Votre code





#s = Fraction(1,1) + Fraction(2,1)
#d = Fraction(-5,6) + Fraction(-2,4)
#print(s,d)
#print(s==d)
#print(s*d)

# %%
# Exercice 1.7 Un intervalle

# Votre code
    
    
    
    
    
    
    
    
    
#print(f"[0,1] est vide : {Intervalle(0,1).est_vide()}")
#print(f"[5,1] est vide : {Intervalle(5,1).est_vide()}")

#print(f"[2,8] a pour longueur {len(Intervalle(2,8))}")
#print(f"[21,8] a pour longueur {len(Intervalle(21,8))}")

#print(f"[2,8] contient 5 : {Intervalle(2,8).contains(5)}")

#print(f"[2,8] et [2,8] sont les memes intervalles : {Intervalle(2,8)==Intervalle(2,8)}")
#print(f"[21,8] et [21,8] sont les memes intervalles : {Intervalle(21,8)==Intervalle(21,8)}")
#print(f"[2,8] et [21,8] sont les memes intervalles : {Intervalle(2,8)==Intervalle(21,8)}")

#print(f"[2,8] est inclu dans [1,8] : {Intervalle(2,8)<=Intervalle(1,8)}")
#print(f"[21,8] est inclu dans [6,3] : {Intervalle(21,8)<=Intervalle(6,3)}")
#print(f"[2,8] est inclu dans [21,8] : {Intervalle(2,8)<=Intervalle(21,8)}")

# %%
# Exercice 1.8 Un jeu de cartes

# Votre Code
        
    
#c1 = Carte()
#print(c1)

#c1.set_valeur(12)
#print(c1)
#c1.set_couleur("Trefle")
#print(c1)

#c1.set_couleur("Violet")

# %% [markdown]
# # Activité : The infinity Train

# %%
class :
    '''
    Creation d'un wagon que l'on attache a une suite de wagons, et ayant 
    un nom, et un numero  (non forcement sa position dans le convoi) 
    (0 = locomotive, 1 = premier wagon, ... )
    
    On pourra donner un numero et un nom par defaut ! 
    
    attributs : precedent, numero, nom
    
    '''
   
    #Votre code 
    
    def __init__( ):
        #Votre code
        
    def __str__():
        #Votre code

# %%
class  :
    '''
    Creation d'un train : on le caracterise par son nom et dernier_wagon puisque 
    ce wagon est reli'e aux autres (le connaissant, on a acces a l'ensemble du train)
    
    attributs : nom, dernier_wagon       
    '''    
    # Votre code
    
    def __init__( ):
        # Votre code
        pass
        
    def est_vide( ):
        #return ....  is None  #attention "is" n'est pas "==" sauf pour None
        pass
    
    
    def ajouter( ): 
        pass
        
        
    def __len__( ):
        #if ... : 
        #    return 0
        #else: 
            # Votre Code
        #    return ...
        pass
        
        
    def __str__(  ):        
        
        #c= ....   #dernier wagon        
        affichage=""  #une proposition
        
        #while ... :
        #    affichage+= ....
        #    c= ....
        #affichage+= .... #nom du train
        return affichage
    
    
    def repartir_sens_inverse(self):
        '''
        on doit donc inverser le train.
        
        - Le plus simple  (propos'e ici) est de copier ce train en sens inverse,
        wagon par wagon et donc de retourner le train invers'e (le train initial sera 
        detruit automatiquement par l'ordinateur, comme on le verra plus tard. 
        cout en espace et moins en temps a priori
        
        - Ou alors d'echanger les oppos'es par rapport au milieu. 
        Mais on doit faire attention si la longueur du train est paire ou impaire  
        et on doit aussi parcourir plusieurs fois le train 
        cout en temps et moins en espace
        
        '''
        
        temp = Train()  #noter la reccursion : un train est cree ... dans le train ! 
        pass
        
    
    def attributs_du_nieme_wagon(self,n :int) -> str:
        '''
        le premier wagon est la tete du train, et le dernier est le dernier wagon ajout'e        
        '''        
        pass
        
    def __add__(self,autre): 
        '''
        On souhaite ajouter deux trains par la commande train+train
        Le wagon 1 du deuxieme doit etre a la position n+1 du premier
        '''
        pass
    
    
    def enlever_wagon(self,n):
        '''
    
        '''
        pass

        

    def inserer_wagon(self, n :int, num :int, nom :str):
        '''
        On veut inserer un wagon en n-ieme position, 
        '''
        pass
            
            
    def tri_train_suivant_numero(self):
        '''
        Un simple tri selection suffit ici mais on peut chercher d'autre facons   
        '''
        pass
            
   
 ## d'autres possibilités de méthodes si vous avez le temps et si ça vous intéresse 
    
    def changer_nom_du_nieme_wagon(self, n :int, nom :str):
        '''
        Pour changer le nom du n-ieme wagon
        '''        
        pass
    
    def trouver_wagon_avec_nom(self):
        '''
        Pour trouver si un wagon particulier (numero et ou nom) se trouve dans le train
        renvoie un booleen
        '''
        pass
    
    def deux_wagons_identique(self):
        '''
        Pour regarder si deux wagons sont identiques (en numero et ou en nom)
        renvoie un booleen
        '''        
        pass
    
    def nombre_de_fois_wagons_idntiques(self):
        '''
        Pour compter le nombre de fois où le numero (et ou nom) apparaissent dans le train
        renvoie un nombre
        '''
        pass 
    
    def copie(self): 
        '''
        Pour copier un train
        renvoie un train
        '''
        pass

# %%
#Pour tester si jamais 
train = Train()
train.est_vide()
train.ajouter(1,"Obi One")
train.ajouter(2,"Mew Two")
train.ajouter(3,"Raspa Tree")
print(f"le train est vide : {train.est_vide()}")
print(f"la longueur du train est de {len(train)} wagons")
print(f"\n le train ressemble à : \n {train} \n")
train.ajouter(4,"Chateau For")
train.repartir_sens_inverse()
print(f"le train (inversé) ressemble à : \n {train} \n")
print(f"le 2 wagon est {train.attributs_du_nieme_wagon(2)}")

train_2 = Train("Loco Loco")
train_2.ajouter(7,"Rap id")
train_2.ajouter(2,"Nes Quick")
train_2.ajouter(9,"Speed i")
print(f"\n le train 2 ressemble à : \n {train_2} \n")

train = train + train_2 
print(f"\n le train ressemble maintenant à : \n {train} \n")

train.enlever_wagon(2)
train.inserer_wagon(2,8,"Love not Height")
print(f"\n le train ressemble maintenant à : \n {train} \n")

train.tri_train_suivant_numero()
print(f"\n le train trié ressemble maintenant à : \n {train} \n")

# %% [markdown]
# # Un jeu de bataille !

# %%
# Affichage de cartes melangees

from random import randrange, shuffle
from tkinter import *


couleur = # tuple avec 4 couleurs
valeur = #tuple avec les differentes couleurs


class Carte(object):
    "Definition d'une carte"

    def __init__():
        #attributs : valeur et couleur d'une carte

    def dessin_carte(self):
        "Renvoi du nom du fichier image de la carte c"
        #mettre les .gif des cartes dans un repertoire
        nom = #
        return PhotoImage(file=nom)   #PhotoImage : voir doc de tkinter

        
class Paquet_de_cartes(object):
    """Paquet de cartes"""
    
    def __init__(self):
        "Construction de la liste des 52 cartes"
        #on pourrait mettre toutes les cartes dans une liste .... 
        #attribut : paquet ou cartes

    def battre(self):
        "Melanger les cartes"
        #On pourra utiliser la fonction Shuffle de Random pour melanger une liste

    def tirer(self):
        "Tirer la premiere carte de la pile"
        # on tire la premiere carte de la pile et on la retire de la pile
        #renvoie le paquet sans cette carte.


# fenetre graphique
fenetre = Tk()
fenetre.title("Cartes")
jeu = Paquet_de_cartes()
jeu.battre()
c = jeu.tirer()
carte1 = c.dessin_carte()
lab1 = Label(fenetre, image=carte1)
lab1.grid(row=0, column=0)
bouton1 = Button(fenetre,text='Tirer',command=jouer)
bouton1.grid(row=1, column=0, sticky=W)
bouton4 = Button(fenetre,text='Recommencer',command=reinit)
bouton4.grid(row=1, column=0, sticky=E)

# demarrage :
fenetre.mainloop()
